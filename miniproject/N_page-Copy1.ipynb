# %%
pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in c:\users\smhrd\anaconda3\lib\site-packages (7.5.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\smhrd\anaconda3\lib\site-packages (from pyngrok) (6.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template
from pyngrok import ngrok

ngrok.set_auth_token("39EmL8daL89Ns4zScKilCqR6waZ_4HqGJF7UTFMLxrnYGVR5o")

app = Flask(__name__)

@app.route('/')
def main():
    return render_template('page0.html')

@app.route('/page1')
def page1():
    return render_template('page1.html')

@app.route('/page2')
def page2():
    return render_template('page2.html')

@app.route('/page3')
def page3():
    return render_template('page3.html')

@app.route('/page4')
def page4():
    return render_template('page4.html')

@app.route('/page5')
def page5():
    return render_template('page5.html')

@app.route('/page6')
def page6():
    return render_template('page6.html')

@app.route('/page7')
def page7():
    return render_template('page7.html')

@app.route('/page8')
def page8():
    return render_template('page8.html')

if __name__ == "__main__":
    # Flask 기본 포트 설정
    port = 5000

    # ngrok 터널 생성
    public_url = ngrok.connect(port)
    print(" * ngrok URL:", public_url)

    # Flask 서버 실행
    app.run(host="127.0.0.1", port=port)
# Out:
#  * ngrok URL: NgrokTunnel: "https://defectless-nonconjunctively-cesar.ngrok-free.dev" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Feb/2026 10:40:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:40:46] "GET /pen1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Feb/2026 10:40:46] "GET /static/WEBTOON_Logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:46] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:48] "GET /page1 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:40:49] "GET /static/anna.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:49] "GET /static/audience.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:49] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:49] "GET /static/genre.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:49] "GET /static/site.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:51] "GET /page2 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/num.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/sea.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/mat.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/cul1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/cul3.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/cul2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/sel.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:52] "GET /static/pan.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:54] "GET /page3 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:40:55] "GET /static/apiA.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:55] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:55] "GET /static/dataset2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:55] "GET /static/dataset.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /page4 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/insight1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/insight4.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/insight2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/insight5.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:40:57] "GET /static/insight3.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:00] "GET /page5 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:41:00] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:03] "GET /page6 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:41:03] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:05] "GET /page7 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:41:05] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:08] "GET /page8 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:41:09] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Feb/2026 10:41:11] "GET /pen1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Feb/2026 10:41:11] "GET /static/bge7.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:11] "GET /static/WEBTOON_Logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Feb/2026 10:41:24] "GET / HTTP/1.1" 200 -
